# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.rcParams['font.sans-serif'] = ['Times New Roman']
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_clipboard()

# %%
df.head()
# Out:
#    1693702261  40.07445318  115.099874  1179.655118  0.22241463  0
# 0  1693702374    40.074363  115.099866  1182.136133    2.104815  0
# 1  1693702378    40.074266  115.099844  1182.172172    2.691498  0
# 2  1693702384    40.074166  115.099823  1181.711146    1.214958  0
# 3  1693702394    40.074063  115.099804  1182.006423    1.036101  0
# 4  1693702404    40.073966  115.099805  1183.771706    1.022656  0

# %%
df.shape
# Out:
# (2178, 6)

# %%
arr = df.iloc[:, 1:3].values

# %%
plt.scatter(arr[:, 0], arr[:, 1])

# %%
df.head()
# Out:
#    1693702261  40.07445318  115.099874  1179.655118  0.22241463  0
# 0  1693702374    40.074363  115.099866  1182.136133    2.104815  0
# 1  1693702378    40.074266  115.099844  1182.172172    2.691498  0
# 2  1693702384    40.074166  115.099823  1181.711146    1.214958  0
# 3  1693702394    40.074063  115.099804  1182.006423    1.036101  0
# 4  1693702404    40.073966  115.099805  1183.771706    1.022656  0

# %%
(df.iloc[:, 4] == 0.044).sum()
# Out:
# 0
